# %%
import numpy as np
import pandas as pd

# %% [markdown]
# https://www.nongnet.or.kr/anss/splyInfo.do  - 농산물 가격 데이터셋 제공
#
# 농업 데이터 가격및 거래량과 날씨간의 상관관계 비교

# %%
train = pd.read_csv("train.csv")
private = pd.read_csv("private_data.csv")

# %%
train
# Out:
#             date   요일  배추_거래량(kg)  배추_가격(원/kg)  무_거래량(kg)  무_가격(원/kg)  \
# 0     2016-01-01  금요일         0.0          0.0        0.0         0.0
# 1     2016-01-02  토요일     80860.0        329.0    80272.0       360.0
# 2     2016-01-03  일요일         0.0          0.0        0.0         0.0
# 3     2016-01-04  월요일   1422742.5        478.0  1699653.7       382.0
# 4     2016-01-05  화요일   1167241.0        442.0  1423482.3       422.0
# ...          ...  ...         ...          ...        ...         ...
# 1728  2020-09-24  목요일   1856965.0       1839.0  2055640.0       990.0
# 1729  2020-09-25  금요일   1880095.5       1789.0  1879261.0      1011.0
# 1730  2020-09-26  토요일   1661090.9       1760.0  1709385.7      1075.0
# 1731  2020-09-27  일요일     25396.0       3066.0    38222.0      1139.0
# 1732  2020-09-28  월요일   2405051.9       1867.0  2747519.5      1147.0
#
#       양파_거래량(kg)  양파_가격(원/kg)  건고추_거래량(kg)  건고추_가격(원/kg)  ...  청상추_거래량(kg)  \
# ...

# %%
private
# Out:
#            date   요일  배추_거래량(kg)  배추_가격(원/kg)  무_거래량(kg)  무_가격(원/kg)  \
# 0    2020-11-06  금요일   2051420.6        493.0  2764127.3       487.0
# 1    2020-11-07  토요일   2042138.9        442.0  2666318.3       479.0
# 2    2020-11-08  일요일         0.0          0.0        0.0         0.0
# 3    2020-11-09  월요일   2848530.8        456.0  3727873.7       438.0
# 4    2020-11-10  화요일   2255125.2        471.0  3199634.2       428.0
# ..          ...  ...         ...          ...        ...         ...
# 286  2021-08-19  목요일    993076.5        626.0   946342.5       474.0
# 287  2021-08-20  금요일   1159824.2        578.0  1042244.6       458.0
# 288  2021-08-21  토요일    977115.9        611.0   928502.8       451.0
# 289  2021-08-22  일요일         0.0          0.0        0.0         0.0
# 290  2021-08-23  월요일    130467.4        644.0   141745.0       501.0
#
#      양파_거래량(kg)  양파_가격(원/kg)  건고추_거래량(kg)  건고추_가격(원/kg)  ...  청상추_거래량(kg)  \
# ...

# %%
df = pd.read_csv("AT_TSALET_ALL_202108.csv")

# %%
df
# Out:
#          SALEDATE WHSAL_NM CMP_NM PUM_NM  KIND_NM DAN_NM POJ_NM   SIZE_NM  \
# 0        20210810   인천삼산도매   경인농산     깻잎   깻잎(일반)     kg     상자         .
# 1        20210810   인천삼산도매   경인농산     깻잎   깻잎(일반)     kg     상자         .
# 2        20210810   인천삼산도매   경인농산     깻잎   깻잎(일반)     kg     상자         .
# 3        20210810   인천삼산도매   경인농산     깻잎      깻잎순     kg     상자         .
# 4        20210810   인천삼산도매   경인농산     깻잎   깻잎(일반)     kg     상자         .
# ...           ...      ...    ...    ...      ...    ...    ...       ...
# 2365201  20210821   서울강서도매   강서청과    바나나  바나나(수입)     kg      .  1개(내_뿌리)
# 2365202  20210821   서울강서도매   강서청과    바나나  바나나(수입)     kg      .  1개(내_뿌리)
# 2365203  20210821   서울강서도매   강서청과    바나나  바나나(수입)     kg      .  1개(내_뿌리)
# 2365204  20210821   서울강서도매   강서청과    바나나  바나나(수입)     kg      .  1개(내_뿌리)
# 2365205  20210821   서울강서도매   강서청과    바나나  바나나(수입)     kg      .  1개(내_뿌리)
#
#         LV_NM    SAN_NM  DANQ   QTY   COST  TOT_QTY   TOT_AMT
# ...

# %% [markdown]
# https://www.data.go.kr/data/15078057/openapi.do - 농업 기상 관측데이터

# %% [markdown]
# https://dacon.io/competitions/official/235801/codeshare/3350?page=1&dtype=recent
