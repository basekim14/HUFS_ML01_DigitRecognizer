# %%
import pandas as pd

# %%
df = pd.read_csv("d.csv")
df.head()
# Out:
#       area  deposit  floor  year       ele  mart    de        ho        pa  \
# 0   99.917    50000      2  2000  0.000095  2.19  3.83  0.555305  0.635911
# 1   99.917    49000      4  2000  0.000095  2.19  3.83  0.555305  0.635911
# 2   99.917    45000      8  2000  0.000095  2.19  3.83  0.555305  0.635911
# 3   99.917    50000      2  2000  0.000095  2.19  3.83  0.555305  0.635911
# 4  134.914    50000      2  2000  0.000095  2.19  3.83  0.555305  0.635911
#
#             su   cc  park  d4  d3  d2  d1  d0
# 0  1042.694537  105   986   0   0   0   0   1
# 1  1042.694537  105   986   0   0   0   0   1
# 2  1042.694537  105   986   0   0   0   0   1
# 3  1042.694537  105   986   0   0   0   0   1
# 4  1042.694537  105   986   0   0   0   0   1

# %%
from sklearn.model_selection import train_test_split

# %%
x=df[['area','floor','year','ele','mart','de','ho','pa','su','cc','park','d4','d3','d2','d1','d0']]

# %%
y = df[['deposit']]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.8, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
mlr = LinearRegression()
mlr.fit(x_train, y_train) 
print(mlr.coef_)
# Out:
# [[ 4.85333330e+02  8.22572812e+01  4.20688704e+02 -4.64540696e+02
#   -2.60436387e+03  1.37052923e+02 -9.03438661e+02 -3.27556409e+03
#   -3.23237197e+00  6.31475058e+00  4.26676084e-01 -2.54379086e+03
#   -1.38205387e+03 -1.92572520e+03 -5.24005955e+02  6.37557588e+03]]

# %%
print(mlr.score(x_train, y_train))
# Out:
# 0.7773073890378255

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
apart = pd.read_csv("test70.csv")
apart_data = apart.drop(['deposit'], axis=1)
x_data = apart[["area","floor","year","ele","mart","de","hos","park","cctv","parking","br"]] 
target = apart[["deposit"]]
x_data1 = sm.add_constant(x_data, has_constant = "add")
multi_model = sm.OLS(target, x_data1)
fitted_multi_model = multi_model.fit()
fitted_multi_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                deposit   R-squared:                       0.761
# Model:                            OLS   Adj. R-squared:                  0.761
# Method:                 Least Squares   F-statistic:                     2986.
# Date:                Sun, 07 Nov 2021   Prob (F-statistic):               0.00
# Time:                        21:40:02   Log-Likelihood:            -1.0531e+05
# No. Observations:               10314   AIC:                         2.107e+05
# Df Residuals:                   10302   BIC:                         2.107e+05
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -8.601e+05   2.58e+04    -33.318      0.000   -9.11e+05   -8.09e+05
# ...
